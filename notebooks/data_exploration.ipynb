# %%
import pandas as pd


df = pd.read_csv("../data/01-01-2021.csv")

df.head(10)

# %%
# Number of rows
print(df.size)

# Number of columns
print(df.columns.size)

# first 10 rows
df.head(10)

# %%
df.count(axis=0)

# %%
df.sample(10)

# %%
df.info()

# %%
df.describe()

# %%
df["Country_Region"].value_counts()

# %%
df.shape

# %%
df.dtypes

# %%
print(df.nunique())

print(df["Country_Region"].unique().size)

# %%
df1 = pd.Series([1, 2, 3])


int(df1.values[2])

# %%
df.dtypes

# %%
df["ingested_at"].head(12)
